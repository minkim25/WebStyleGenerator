# %%
import pytumblr

# %%
# Authenticate via OAuth
# We only need the consumer key to call "posts" function
client = pytumblr.TumblrRestClient('nAvaCgNT6dVls4dxKYnWyM1as57L0aSAkSXAayRCPEtNxJSQjr')

# %%
# Make the request
# I just created a new one to test. You can take a look how the result is going to be
client.posts('minkim25.tumblr.com')
# Out:
# {'blog': {'ask': False,
#   'ask_anon': False,
#   'ask_page_title': 'Ask me anything',
#   'can_chat': True,
#   'can_subscribe': False,
#   'description': '',
#   'is_nsfw': False,
#   'likes': 0,
#   'name': 'minkim25',
#   'posts': 2,
#   'share_likes': True,
#   'subscribed': False,
#   'title': 'Untitled',
#   'total_posts': 2,
#   'updated': 1573595597,
#   'url': 'https://minkim25.tumblr.com/',
#   'uuid': 't:6LEN8k8HUdwNtZulc7yx8g',
#   'is_optout_ads': False},
#  'posts': [{'type': 'text',
#    'blog_name': 'minkim25',
#    'blog': {'name': 'minkim25',
#     'title': 'Untitled',
#     'description': '',
#     'url': 'https://minkim25.tumblr.com/',
#     'uuid': 't:6LEN8k8HUdwNtZulc7yx8g',
#     'updated': 1573595597},
#    'id': 189022392405,
#    'post_url': 'https://minkim25.tumblr.com/post/189022392405/second-one',
#    'slug': 'second-one',
#    'date': '2019-11-12 21:53:17 GMT',
#    'timestamp': 1573595597,
#    'state': 'published',
#    'format': 'html',
#    'reblog_key': '9oLTzjE2',
#    'tags': [],
#    'short_url': 'https://tmblr.co/ZA9VoV2m2dD1L',
#    'summary': 'second one...',
#    'should_open_in_legacy': False,
#    'recommended_source': None,
#    'recommended_color': None,
#    'note_count': 0,
#    'title': 'second one...',
#    'body': '<p>as written in title&hellip;</p><p>one two three</p><p>test test test</p>',
#    'reblog': {'comment': '<p>as written in title…</p><p>one two three</p><p>test test test</p>',
#     'tree_html': ''},
#    'trail': [{'blog': {'name': 'minkim25',
#       'active': True,
#       'theme': {'avatar_shape': 'circle',
#        'background_color': '#FAFAFA',
#        'body_font': 'Helvetica Neue',
#        'header_bounds': '',
#        'header_image': 'https://assets.tumblr.com/images/default_header/optica_pattern_07.png?_v=c52eb3e7fd4be5c98b8970b4c330d172',
#        'header_image_focused': 'https://assets.tumblr.com/images/default_header/optica_pattern_07_focused_v3.png?_v=c52eb3e7fd4be5c98b8970b4c330d172',
#        'header_image_scaled': 'https://assets.tumblr.com/images/default_header/optica_pattern_07_focused_v3.png?_v=c52eb3e7fd4be5c98b8970b4c330d172',
#        'header_stretch': True,
#        'link_color': '#529ECC',
#        'show_avatar': True,
#        'show_description': True,
#        'show_header_image': True,
#        'show_title': True,
#        'title_color': '#444444',
#        'title_font': 'Gibson',
#        'title_font_weight': 'bold'},
#       'share_likes': True,
#       'share_following': True,
#       'can_be_followed': True},
#      'post': {'id': '189022392405'},
#      'content_raw': '<p>as written in title…</p><p>one two three</p><p>test test test</p>',
#      'content': '<p>as written in title&hellip;</p><p>one two three</p><p>test test test</p>',
#      'is_current_item': True,
#      'is_root_item': True}],
#    'can_like': False,
#    'can_reblog': False,
#    'can_send_in_message': True,
#    'can_reply': False,
#    'display_avatar': True},
#   {'type': 'text',
#    'blog_name': 'minkim25',
#    'blog': {'name': 'minkim25',
#     'title': 'Untitled',
#     'description': '',
#     'url': 'https://minkim25.tumblr.com/',
#     'uuid': 't:6LEN8k8HUdwNtZulc7yx8g',
#     'updated': 1573595597},
#    'id': 189022342220,
#    'post_url': 'https://minkim25.tumblr.com/post/189022342220/first-post',
#    'slug': 'first-post',
#    'date': '2019-11-12 21:50:52 GMT',
#    'timestamp': 1573595452,
#    'state': 'published',
#    'format': 'html',
#    'reblog_key': 'jrE9hHbB',
#    'tags': [],
#    'short_url': 'https://tmblr.co/ZA9VoV2m2d0nC',
#    'summary': 'first post',
#    'should_open_in_legacy': False,
#    'recommended_source': None,
#    'recommended_color': None,
#    'note_count': 0,
#    'title': 'first post',
#    'body': '<p>This is Young’s first post written for a test purpose.\xa0</p><p>Currently working on \n\nCMPT732-Project-PieSparkDayum.</p><p>Let’s go Dayum!</p>',
#    'reblog': {'comment': '<p>This is Young’s first post written for a test purpose.\xa0</p><p>Currently working on \n\nCMPT732-Project-PieSparkDayum.</p><p>Let’s go Dayum!</p>',
#     'tree_html': ''},
#    'trail': [{'blog': {'name': 'minkim25',
#       'active': True,
#       'theme': {'avatar_shape': 'circle',
#        'background_color': '#FAFAFA',
#        'body_font': 'Helvetica Neue',
#        'header_bounds': '',
#        'header_image': 'https://assets.tumblr.com/images/default_header/optica_pattern_07.png?_v=c52eb3e7fd4be5c98b8970b4c330d172',
#        'header_image_focused': 'https://assets.tumblr.com/images/default_header/optica_pattern_07_focused_v3.png?_v=c52eb3e7fd4be5c98b8970b4c330d172',
#        'header_image_scaled': 'https://assets.tumblr.com/images/default_header/optica_pattern_07_focused_v3.png?_v=c52eb3e7fd4be5c98b8970b4c330d172',
#        'header_stretch': True,
#        'link_color': '#529ECC',
#        'show_avatar': True,
#        'show_description': True,
#        'show_header_image': True,
#        'show_title': True,
#        'title_color': '#444444',
#        'title_font': 'Gibson',
#        'title_font_weight': 'bold'},
#       'share_likes': True,
#       'share_following': True,
#       'can_be_followed': True},
#      'post': {'id': '189022342220'},
#      'content_raw': '<p>This is Young’s first post written for a test purpose.\xa0</p><p>Currently working on \n\nCMPT732-Project-PieSparkDayum.</p><p>Let’s go Dayum!</p>',
#      'content': '<p>This is Young&rsquo;s first post written for a test purpose.&nbsp;</p><p>Currently working on \n\nCMPT732-Project-PieSparkDayum.</p><p>Let&rsquo;s go Dayum!</p>',
#      'is_current_item': True,
#      'is_root_item': True}],
#    'can_like': False,
#    'can_reblog': False,
#    'can_send_in_message': True,
#    'can_reply': False,
#    'display_avatar': True}],
#  'total_posts': 2,
#  '_links': {'next': {'href': '/v2/blog/minkim25.tumblr.com/posts?offset=20&page_number=2',
#    'method': 'GET',
#    'query_params': {'offset': '20', 'page_number': '2'}}}}
